# %% [markdown]
# # Librerías externas

# %% [markdown]
# **¿Qué es una librería?**
#
# - Nos permite agregar funciones
# - Son diseñadas por programadores y compartidas
# - Facilitan la tarea de programar ya que proveen nuevas estructuras de datos implementadas
# - Hay librerías para hacer visualizaciones
# - Hay librerías para trabajar con información geográfica
# - Hay librerías para hacer Machine Learning
#
# ¿Qué mas se les ocurre?

# %% [markdown]
# ---
#
#
# Les cuento algo 🤫
#
# En realidad la traducción correcta de "library" debería ser "biblioteca"... Pero library, librería ¿No suena mejor?
#
#
# ---

# %% [markdown]
# En la notebook anterior, importamos una librería llamada "random" que nos permite por ejemplo generar números al azar y mezclar listas. Simplemente con escribir en nuestro bloque de código `import random` las funciones que nos provee ya estarán disponibles, ya que es una librería que viene instalada con Python. Pero no siempre es el caso... ¿Y qué sucede cuando una librería no viene instalada?

# %% [markdown]
# ---
#
#
# #PIP - Gestor de paquetes
#
# pip es un gestor de paquetes o gestor de librerías.
#
# [Guía para instalar pip en Linux, Windows y Mac](https://tecnonucleous.com/2018/01/28/como-instalar-pip-para-python-en-windows-mac-y-linux/)

# %% [markdown]
# Desde Google Colaboratory, si queremos instalar un paquete que no esté  disponible, lo hacemos por linea de comandos de la siguiente manera:

# %%
# !pip install telegram

# %% [markdown]
# Desde nuestra computadora, directamente por linea de comandos sin el `!`:
#
# `pip install telegram`

# %% [markdown]
# Listemos algunas librerías (que vengan preinstaladas con python o no) que vayamos a utilizar y otras que conozcan:
#
# - pandas
# - matplotlib
# - seaborn
# - numpy
# - pyseoanalyzer (SEO - Search Engine Optimization)
